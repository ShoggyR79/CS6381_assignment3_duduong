# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_normal = pd.read_csv('output_normal.csv')
df_broker = pd.read_csv('output_broker.csv')
df_discovery_dead = pd.read_csv('output_discovery_dead.csv')
df_broker_dead = pd.read_csv('output_broker_dead.csv')

# %%
df_normal.head()
# Out:
#        Time   Latency
# 0  0.262834  0.000692
# 1  0.192487  0.000903
# 2  0.869450  0.000766
# 3  0.263155  0.000863
# 4  0.192742  0.001008

# %%
plt.plot(df_normal['Time'], df_normal['Latency'])

# %%
plt.plot(df_broker['Time'], df_broker['Latency'])

# %%
plt.plot(df_discovery_dead['Time'], df_discovery_dead['Latency'])

# %%
plt.plot(df_broker_dead['Time'], df_broker_dead['Latency'])
